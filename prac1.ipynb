# %%
import cv2
from matplotlib import pyplot as plt

# %%
name = input("Image name: ")
img=cv2.imread(name)
image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# Out:
# Image name: moon.png

# %%
plt.imshow(image)
plt.axis('off')
plt.show()
